# %%
import pandas as pd
import requests
import os
import dotenv
from utils.AlterscopeAPI import AlterscopeAPI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_key =  os.getenv('ALTERSCOPE_API_KEY', None)

# %%
alterscope_api = AlterscopeAPI(api_key)

# %% [markdown]
# ##### example 1: get protocol development

# %%
alterscope_api.get_protocol_development('aave')
# Out:
# {'status': True,
#  'data': [{'activity_events': 13,
#    'branches': 36,
#    'collaborators': -1,
#    'commit_comments': 0,
#    'top_contributor_weight': 69.76744186046511,
#    'contributors': 7,
#    'contributions_mean': 30.714285714285715,
#    'contributions_absolute_deviation': 34.08163265306123,
#    'gini_coefficient': 0.6697674418604651,
#    'num_issues': 26,
#    'num_issues_events': 326,
#    'num_pulls': 7,
#    'repos': 76,
#    'num_commit_t': 215,
#    'num_commit_w': 0,
#    'num_commit_m': 0,
#    'url': 'https://github.com/aave/protocol-subgraphs',
#    'timestamp': '2024-01-31T04:06:38.792913439Z',
#    'forks': 89,
#    'watchers': 11,
#    'stars': 101},
#   {'activity_events': 292,
#    'branches': 35,
#    'collaborators': -1,
#    'commit_comments': 1,
#    'top_contributor_weight': 69.36170212765957,
#    'contributors': 13,
#    'contributions_mean': 18.076923076923077,
#    'contributions_absolute_deviation': 23.207100591715975,
# ...

# %% [markdown]
# ##### example 2: get protocol community sentiment

# %%
alterscope_api.get_protocol_discord_sentiment('aave')
# Out:
# {'status': True,
#  'data': [{'channel': 'discord',
#    'daily_message_count': 48,
#    'number_of_unique_users': 17,
#    'average_sentiment_score': 0.30208333333333337,
#    'high_level_topic_frequency': [{'topic': 'Other', 'frequency': 13},
#     {'topic': 'Community and Communication', 'frequency': 9},
#     {'topic': 'DeFi and Yield Farming', 'frequency': 8},
#     {'topic': 'Technical Discussions and Support', 'frequency': 7},
#     {'topic': 'Price and Market Discussions', 'frequency': 4},
#     {'topic': 'Data and Analytics', 'frequency': 4},
#     {'topic': 'Trading and Tokens', 'frequency': 2},
#     {'topic': 'Scams and Security', 'frequency': 1}],
#    'mid_level_topic_based_sentiment_distrubution': [{'topic_name': 'APR and Projected APY Discussion',
#      'count': 1,
#      'neutral_sentiment_count': 1,
#      'positive_sentiment_count': 0,
#      'negative_sentiment_count': 0,
#      'high_level_category': 'Other'},
# ...
